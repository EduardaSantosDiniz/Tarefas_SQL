# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardaSantosDiniz/Tarefas_SQL/blob/main/PraticandoPythonPowerBi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('uber_fortaleza.csv')
destinos = data['Destino'].value_counts()

data.head()
# Out:
#    Unnamed: 0                    Origem             Destino           Dia  \
# 0           0           Dionísio Torres             Aldeota  Quinta-Feira
# 1           1                  Meireles          Guararapes  Quarta-Feira
# 2           2                Cajazeiras           Messejana       Domingo
# 3           3  Parque Presidente Vargas  Conjunto Palmeiras   Sexta-Feira
# 4           4                Cajazeiras          Guararapes        Sábado
#
#    Hora  Preço
# 0  13.0  11.18
# 1  12.0  13.90
# 2   5.0  13.78
# 3  16.0  19.27
# 4  20.0  14.08

# %%
destinos = data['Destino'].value_counts()
media = data['Preço'].mean()

plt.bar(destinos.index, contagem.values)
plt.xlabel('Destino')
plt.ylabel('Preço')
plt.title('Gráfico de Barras')

plt.show()

# %%
destinos = data['Destino'].value_counts()
media = data['Preço'].mean()
plt.figure(figsize=(27, 6))
plt.bar(destinos.index, contagem.values, color = ('0.40', '0.20', '0.80'))
plt.xlabel('Destino')
plt.ylabel('Preço')
plt.title('Gráfico de Barras')

plt.show()
