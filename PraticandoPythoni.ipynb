# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardaSantosDiniz/Tarefas_SQL/blob/main/PraticandoPythoni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('uber_fortaleza.csv')
destinos = df['Destino']#.value_counts()
precos_media_dia = df.groupby('Dia')['Preço'].mean()
dias = df['Dia']

print(precos_media_dia)
# Out:
# Dia
# Domingo          15.106063
# Quarta-Feira     15.635791
# Quinta-Feira     15.523674
# Segunda-Feira    15.668164
# Sexta-Feira      15.508708
# Sábado           15.117957
# Terça-Feira      15.521637
# Name: Preço, dtype: float64

# %%
ordem_dias = ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta', 'Sábado', 'Domingo']
df ['Dia'] = pd.Categorical(df['Dia'], categories = ordem_dias, ordered = True)
precos_media_dia = df.groupby('Dia')['Preço'].mean()
#x = df ['Dia'].values
#y = precos_media_dia.values
x = precos_media_dia.values
y = precos_media_dia.values

plt.figure(figsize = (15,3))

plt.plot(x, y)
plt.show()
# Out:
# /tmp/ipython-input-78-3745386844.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   precos_media_dia = df.groupby('Dia')['Preço'].mean()

# %%
destinos = data['Destino'].value_counts()
media = data['Preço'].mean()
plt.figure(figsize=(27, 6))
plt.bar(destinos.index, contagem.values, color = ('0.40', '0.20', '0.80'))
plt.xlabel('Destino')
plt.ylabel('Preço')
plt.title('Gráfico de Barras')

plt.show()
